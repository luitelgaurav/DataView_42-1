# %%
# !pip install nba_api
import json
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import shotchartdetail,playergamelog,leaguestandings,commonplayerinfo
from nba_api.stats.static import players , teams

# %% [markdown]
# ## Load the Players IDs

# %%
# nba_api/stats/static/players.py
list_players=players.get_active_players()
# list_players

# %%
df_players=pd.DataFrame(list_players)

# %%
players_ids = [item['id'] for item in list_players]
# players_ids

# %%
df_players.to_csv('NBA_Players.csv',index=False)

# %% [markdown]
# ## Load the Team IDs

# %%
# nba_api/stats/static/players.py
df_teams=pd.DataFrame(teams.get_teams())

# %%
df_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
df_teams.to_csv('NBA_Teams.csv',index=False)

# %% [markdown]
# ## Load Shooting Data

# %%
#For all active players
for ID in players_ids:
    response = shotchartdetail.ShotChartDetail(
        team_id=0,
        player_id=ID,
        season_nullable='2021-22',
        season_type_all_star='Regular Season',
        context_measure_simple='FGA'
    )
    content = json.loads(response.get_json())
    
    # transform contents into dataframe
    if(ID==players_ids[0]):
        results = content['resultSets'][0]
        headers = results['headers']
        rows = results['rowSet']
        df_active_players = pd.DataFrame(rows)
        df_active_players.columns = headers
    else:
        results = content['resultSets'][0]
        rows = results['rowSet']
        if(len(rows)==0):
            continue
        df = pd.DataFrame(rows)
        df.columns = headers
        df_active_players=pd.concat([df_active_players,df])

# %%
df_active_players
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0    Shot Chart Detail  0022100006             14    1630173
# 1    Shot Chart Detail  0022100006             28    1630173
# 2    Shot Chart Detail  0022100006             33    1630173
# 3    Shot Chart Detail  0022100006             45    1630173
# 4    Shot Chart Detail  0022100006            231    1630173
# ..                 ...         ...            ...        ...
# 490  Shot Chart Detail  0022101222            236    1627826
# 491  Shot Chart Detail  0022101222            251    1627826
# 492  Shot Chart Detail  0022101222            263    1627826
# 493  Shot Chart Detail  0022101222            282    1627826
# 494  Shot Chart Detail  0022101222            328    1627826
#
#           PLAYER_NAME     TEAM_ID        TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0    Precious Achiuwa  1610612761  Toronto Raptors       1                 10
# 1    Precious Achiuwa  1610612761  Toronto Raptors       1                  9
# 2    Precious Achiuwa  1610612761  Toronto Raptors       1                  9
# 3    Precious Achiuwa  1610612761  Toronto Raptors       1                  7
# 4    Precious Achiuwa  1610612761  Toronto Raptors       2                  8
# ..                ...         ...              ...     ...                ...
# 490       Ivica Zubac  1610612746      LA Clippers       2                  4
# 491       Ivica Zubac  1610612746      LA Clippers       2                  3
# 492       Ivica Zubac  1610612746      LA Clippers       2                  2
# 493       Ivica Zubac  1610612746      LA Clippers       2                  0
# 494       Ivica Zubac  1610612746      LA Clippers       3                  8
#
#      SECONDS_REMAINING  ... SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE  \
# 0                   37  ...      Center(C)  Less Than 8 ft.             2
# 1                   29  ...      Center(C)  Less Than 8 ft.             1
# 2                    1  ...      Center(C)  Less Than 8 ft.             0
# 3                   51  ...      Center(C)  Less Than 8 ft.             0
# 4                   34  ...      Center(C)  Less Than 8 ft.             0
# ..                 ...  ...            ...              ...           ...
# 490                 47  ...      Center(C)  Less Than 8 ft.             0
# 491                 11  ...      Center(C)  Less Than 8 ft.             6
# 492                  9  ...      Center(C)  Less Than 8 ft.             4
# 493                 49  ...      Center(C)  Less Than 8 ft.             0
# 494                 47  ...      Center(C)  Less Than 8 ft.             5
#
#     LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0     -17    13                   1               0   20211020  TOR  WAS
# 1      10    -3                   1               0   20211020  TOR  WAS
# 2       5     0                   1               1   20211020  TOR  WAS
# 3      -5     7                   1               0   20211020  TOR  WAS
# 4       0     0                   1               0   20211020  TOR  WAS
# ..    ...   ...                 ...             ...        ...  ...  ...
# 490     0     0                   1               1   20220410  LAC  OKC
# 491   -16    61                   1               1   20220410  LAC  OKC
# 492    18    37                   1               0   20220410  LAC  OKC
# 493     0     0                   1               1   20220410  LAC  OKC
# 494     2    55                   1               1   20220410  LAC  OKC
#
# [213424 rows x 24 columns]

# %%
df_active_players.to_csv('NBA_Active_Players_Data_14-04-2022.csv',index=False)

# %% [markdown]
# ## Load PLayers Stats

# %%
#For all active players
for ID in players_ids:
    response = playergamelog.PlayerGameLog(
        player_id=ID,
        season='2021-22',
        season_type_all_star='Regular Season'
    )
    content = json.loads(response.get_json())
    
    # transform contents into dataframe
    if(ID==players_ids[0]):
        results = content['resultSets'][0]
        headers = results['headers']
        rows = results['rowSet']
        df_players_stats = pd.DataFrame(rows)
        df_players_stats.columns = headers
    else:
        results = content['resultSets'][0]
        rows = results['rowSet']
        if(len(rows)==0):
            continue
        df = pd.DataFrame(rows)
        df.columns = headers
        df_players_stats=pd.concat([df_players_stats,df])

# %%
df_players_stats
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      22021    1630173  0022101226  APR 10, 2022    TOR @ NYK  L   26    4
# 1      22021    1630173  0022101206  APR 08, 2022  TOR vs. HOU  W   12    2
# 2      22021    1630173  0022101197  APR 07, 2022  TOR vs. PHI  W   40    7
# 3      22021    1630173  0022101182  APR 05, 2022  TOR vs. ATL  W   24    4
# 4      22021    1630173  0022101172  APR 03, 2022  TOR vs. MIA  L   21    1
# ..       ...        ...         ...           ...          ... ..  ...  ...
# 71     22021    1627826  0022100076  OCT 29, 2021    LAC @ POR  L   22    1
# 72     22021    1627826  0022100064  OCT 27, 2021  LAC vs. CLE  L   24    4
# 73     22021    1627826  0022100049  OCT 25, 2021  LAC vs. POR  W   25    5
# 74     22021    1627826  0022100034  OCT 23, 2021  LAC vs. MEM  L   19    3
# 75     22021    1627826  0022100016  OCT 21, 2021    LAC @ GSW  L   17    4
#
#     FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0    13   0.308  ...     4    6    2    1    1    1   2    9          -7
# 1     5   0.400  ...     1    1    0    0    1    2   2    8         -28
# 2    11   0.636  ...     3    4    2    1    1    5   1   20           5
# 3    11   0.364  ...     1    2    0    1    0    0   1   11          21
# 4     4   0.250  ...     2    2    1    0    0    1   2    3          -2
# ..  ...     ...  ...   ...  ...  ...  ...  ...  ...  ..  ...         ...
# 71    5   0.200  ...     3    5    1    0    2    1   2    3         -16
# 72    6   0.667  ...     2    4    1    0    1    0   3   11          -8
# 73    6   0.833  ...     8    8    4    2    0    1   0   10          14
# 74    7   0.429  ...     4    8    3    0    0    0   2    6         -18
# 75    7   0.571  ...     2    3    2    0    0    0   2   14         -14
#
#     VIDEO_AVAILABLE
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 71                1
# 72                1
# 73                1
# 74                1
# 75                1
#
# [25301 rows x 27 columns]

# %%
df_players_stats.to_csv('NBA_Players_Stats_Data_14-04-2022.csv',index=False)

# %% [markdown]
# ## Load Season Standindgs

# %%
response = leaguestandings.LeagueStandings(
    league_id='00',
    season='2021-22',
    season_type='Regular Season'
)

content = json.loads(response.get_json())

# %%
# transform contents into dataframe
results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
teams_standings = pd.DataFrame(rows)
teams_standings.columns = headers

# %%
teams_standings.head()
# Out:
#   LeagueID SeasonID      TeamID      TeamCity   TeamName Conference  \
# 0       00    22021  1610612756       Phoenix       Suns       West
# 1       00    22021  1610612748         Miami       Heat       East
# 2       00    22021  1610612738        Boston    Celtics       East
# 3       00    22021  1610612763       Memphis  Grizzlies       West
# 4       00    22021  1610612744  Golden State   Warriors       West
#
#   ConferenceRecord  PlayoffRank ClinchIndicator   Division  ...   May   Jun  \
# 0            39-13            1             - w    Pacific  ...  None  None
# 1            35-17            1             - e  Southeast  ...  None  None
# 2            33-19            2             - a   Atlantic  ...  None  None
# 3            36-16            2            - sw  Southwest  ...  None  None
# 4            33-19            3             - x    Pacific  ...  None  None
#
#     Jul   Aug   Sep  Oct   Nov   Dec  PreAS PostAS
# 0  None  None  None  2-3  16-0   9-5  48-10   16-8
# 1  None  None  None  5-1   8-7  10-5  38-21   15-8
# 2  None  None  None  2-4   9-6   6-9  34-26   17-5
# 3  None  None  None  3-3   8-7  12-4  41-19   15-7
# 4  None  None  None  5-1  13-2   9-4  42-17  11-12
#
# [5 rows x 81 columns]

# %%
teams_standings.to_csv('NBA_Season_Team_Standings.csv',index=False)

# %% [markdown]
# ## Player Info

# %%
for ID in df_players['id']:
    response = commonplayerinfo.CommonPlayerInfo(
        player_id=ID,
    )

    content = json.loads(response.get_json())

    # transform contents into dataframe
    if(ID==df_players['id'][0]):
        results = content['resultSets'][0]
        headers = results['headers']
        rows = results['rowSet']
        df_players_info = pd.DataFrame(rows)
        df_players_info.columns = headers
    else:
        results = content['resultSets'][0]
        rows = results['rowSet']
        if(len(rows)==0):
            continue
        df = pd.DataFrame(rows)
        df.columns = headers
        df_players_info=pd.concat([df_players_info,df])

# %%
df_players_info.reset_index(inplace=True,drop=True)

# %%
df_players_info.head(3)
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0    1630173   Precious   Achiuwa   Precious Achiuwa        Achiuwa, Precious
# 1     203500     Steven     Adams       Steven Adams            Adams, Steven
# 2    1628389        Bam   Adebayo        Bam Adebayo             Adebayo, Bam
#
#   DISPLAY_FI_LAST       PLAYER_SLUG   BIRTHDATE      SCHOOL      COUNTRY  ...  \
# 0      P. Achiuwa  precious-achiuwa  1999-09-19     Memphis      Nigeria  ...
# 1        S. Adams      steven-adams  1993-07-20  Pittsburgh  New Zealand  ...
# 2      B. Adebayo       bam-adebayo  1997-07-18    Kentucky          USA  ...
#
#          PLAYERCODE FROM_YEAR TO_YEAR  DLEAGUE_FLAG NBA_FLAG  \
# 0  precious_achiuwa      2020    2021             N        Y
# 1      steven_adams      2013    2021             N        Y
# 2       bam_adebayo      2017    2021             N        Y
#
#   GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND  DRAFT_NUMBER GREATEST_75_FLAG
# 0                 Y       2020           1            20                N
# 1                 Y       2013           1            12                N
# 2                 Y       2017           1            14                N
#
# [3 rows x 33 columns]

# %%
df_players_info.columns
# Out:
# Index(['PERSON_ID', 'FIRST_NAME', 'LAST_NAME', 'DISPLAY_FIRST_LAST',
#        'DISPLAY_LAST_COMMA_FIRST', 'DISPLAY_FI_LAST', 'PLAYER_SLUG',
#        'BIRTHDATE', 'SCHOOL', 'COUNTRY', 'LAST_AFFILIATION', 'HEIGHT',
#        'WEIGHT', 'SEASON_EXP', 'JERSEY', 'POSITION', 'ROSTERSTATUS',
#        'GAMES_PLAYED_CURRENT_SEASON_FLAG', 'TEAM_ID', 'TEAM_NAME',
#        'TEAM_ABBREVIATION', 'TEAM_CODE', 'TEAM_CITY', 'PLAYERCODE',
#        'FROM_YEAR', 'TO_YEAR', 'DLEAGUE_FLAG', 'NBA_FLAG', 'GAMES_PLAYED_FLAG',
#        'DRAFT_YEAR', 'DRAFT_ROUND', 'DRAFT_NUMBER', 'GREATEST_75_FLAG'],
#       dtype='object')

# %%
df_players_info=df_players_info[['PERSON_ID','DISPLAY_FIRST_LAST',
       'BIRTHDATE', 'SCHOOL', 'COUNTRY', 'HEIGHT',
       'WEIGHT', 'SEASON_EXP', 'JERSEY', 'POSITION','FROM_YEAR','DRAFT_YEAR']]
df_players_info.head(3)
# Out:
#    PERSON_ID DISPLAY_FIRST_LAST  BIRTHDATE      SCHOOL      COUNTRY HEIGHT  \
# 0    1630173   Precious Achiuwa 1999-09-19     Memphis      Nigeria    6-8
# 1     203500       Steven Adams 1993-07-20  Pittsburgh  New Zealand   6-11
# 2    1628389        Bam Adebayo 1997-07-18    Kentucky          USA    6-9
#
#   WEIGHT  SEASON_EXP JERSEY        POSITION FROM_YEAR DRAFT_YEAR
# 0    225           1      5         Forward      2020       2020
# 1    265           8      4          Center      2013       2013
# 2    255           4     13  Center-Forward      2017       2017

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
# df_players_info['BIRTHDATE']=df_players_info['BIRTHDATE'].str[:10]
# df_players_info['BIRTHDATE']=pd.to_datetime(df_players_info['BIRTHDATE'], format='%Y-%m-%d')

# %%
player_age = relativedelta(datetime.now(), df_players_info['BIRTHDATE'][0]).years
player_age
# Out:
# 22

# %%
height=int(df_players_info['HEIGHT'][0].split('-')[0])*30.48 + int(df_players_info['HEIGHT'][0].split('-')[1])*2.54
height/=100
height=np.round(height,2)
height #In meters
# Out:
# 2.03

# %%
weight=int(df_players_info['WEIGHT'][0])*0.45359237
weight #In KGs
# Out:
# 102.05828325

# %%
df_players_info.to_csv('NBA_Players_Info.csv',index=False)
